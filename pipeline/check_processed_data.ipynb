# %%
import pandas as pd
df = pd.read_parquet('data/processed/breed_profiles.parquet')
df.shape
# Out:
# (190, 30)

# %%
import pandas as pd
df = pd.read_parquet('data/processed/breed_profiles.parquet')
df['starting_trust'].describe()
# Out:
# count    190.000000
# mean      61.697368
# std        6.091033
# min       40.300000
# 25%       59.200000
# 50%       63.300000
# 75%       66.600000
# max       70.000000
# Name: starting_trust, dtype: float64

# %%
import pandas as pd
df = pd.read_parquet('data/processed/breed_profiles.parquet')
df.isnull().sum()
# Out:
# breed                       0
# description                 0
# temperament                 0
# group                       0
# min_expectancy              2
# max_expectancy              2
# grooming_frequency_value    0
# shedding_value              0
# energy_level_value          0
# trainability_value          0
# demeanor_value              0
# apartment_friendly          0
# novice_owner_friendly       0
# sensitivity                 0
# tolerates_alone             0
# tolerates_cold              0
# tolerates_hot               0
# affectionate                0
# stranger_friendly           0
# shedding_dt                 0
# drooling                    0
# grooming_ease               0
# general_health              0
# weight_gain_risk            0
# bark_tendency               0
# energy_level_dt             0
# exercise_needs              0
# playfulness                 0
# avg_days_in_shelter         0
# starting_trust              0
# dtype: int64

# %%
import pandas as pd
df = pd.read_parquet('data/processed/breed_profiles.parquet')
df.duplicated(subset=['breed']).sum()
# Out:
# np.int64(0)
