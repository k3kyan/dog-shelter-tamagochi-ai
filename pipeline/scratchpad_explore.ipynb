# %%
import pandas as pd
akc = pd.read_csv('data/raw/akc-dog-breeds.csv')
akc.head()
# Out:
#          Unnamed: 0                                        description  \
# 0     Affenpinscher  The Affen’s apish look has been described many...
# 1      Afghan Hound  The Afghan Hound is an ancient breed, his whol...
# 2  Airedale Terrier  The Airedale Terrier is the largest of all ter...
# 3             Akita  Akitas are burly, heavy-boned spitz-type dogs ...
# 4  Alaskan Malamute  The Alaskan Malamute stands 23 to 25 inches at...
#
#                                  temperament popularity  min_height  \
# 0        Confident, Famously Funny, Fearless        148       22.86
# 1  Dignified, Profoundly Loyal, Aristocratic        113       63.50
# 2               Friendly, Clever, Courageous         60       58.42
# 3    Courageous, Dignified, Profoundly Loyal         47       60.96
# 4               Affectionate, Loyal, Playful         58       58.42
#
#    max_height  min_weight  max_weight  min_expectancy  max_expectancy  ...  \
# ...

# %%
import pandas as pd
akc = pd.read_csv('data/raw/akc-dog-breeds.csv')
akc[['grooming_frequency_value','shedding_value',
            'energy_level_value','trainability_value','demeanor_value']].head(10)
# Out:
#    grooming_frequency_value  shedding_value  energy_level_value  \
# 0                       0.6             0.6                 0.6
# 1                       0.8             0.2                 0.8
# 2                       0.6             0.4                 0.6
# 3                       0.8             0.6                 0.8
# 4                       0.6             0.6                 0.8
# 5                       0.2             0.6                 0.8
# 6                       0.2             0.4                 0.8
# 7                       0.4             0.6                 0.8
# 8                       0.2             0.6                 0.8
# 9                       NaN             NaN                 NaN
#
#    trainability_value  demeanor_value
# 0                 0.8             1.0
# 1                 0.2             0.2
# 2                 1.0             0.8
# 3                 1.0             0.6
# 4                 0.4             0.8
# ...

# %%
import pandas as pd
akc = pd.read_csv('data/raw/akc-dog-breeds.csv')
akc['temperament'].head(5)
# Out:
# 0          Confident, Famously Funny, Fearless
# 1    Dignified, Profoundly Loyal, Aristocratic
# 2                 Friendly, Clever, Courageous
# 3      Courageous, Dignified, Profoundly Loyal
# 4                 Affectionate, Loyal, Playful
# Name: temperament, dtype: str

# %%
import pandas as pd
akc = pd.read_csv('data/raw/akc-dog-breeds.csv')
akc['description'].head(5)
# Out:
# 0    The Affen’s apish look has been described many...
# 1    The Afghan Hound is an ancient breed, his whol...
# 2    The Airedale Terrier is the largest of all ter...
# 3    Akitas are burly, heavy-boned spitz-type dogs ...
# 4    The Alaskan Malamute stands 23 to 25 inches at...
# Name: description, dtype: str

# %%
import pandas as pd
akc = pd.read_csv('data/raw/akc-dog-breeds.csv')
akc.isnull().sum()
# Out:
# Unnamed: 0                      0
# description                     0
# temperament                     1
# popularity                     79
# min_height                      0
# max_height                      0
# min_weight                      2
# max_weight                      2
# min_expectancy                  3
# max_expectancy                  3
# group                           0
# grooming_frequency_value        7
# grooming_frequency_category     7
# shedding_value                 20
# shedding_category              20
# energy_level_value              6
# energy_level_category           6
# trainability_value             24
# trainability_category          24
# demeanor_value                 25
# demeanor_category              25
# dtype: int64

# %%
import pandas as pd
akc = pd.read_csv('data/raw/akc-dog-breeds.csv')
akc.shape
# Out:
# (277, 21)

# %%
import pandas as pd
akc = pd.read_csv('data/raw/akc-dog-breeds.csv')
akc.columns
# Out:
# Index(['Unnamed: 0', 'description', 'temperament', 'popularity', 'min_height',
#        'max_height', 'min_weight', 'max_weight', 'min_expectancy',
#        'max_expectancy', 'group', 'grooming_frequency_value',
#        'grooming_frequency_category', 'shedding_value', 'shedding_category',
#        'energy_level_value', 'energy_level_category', 'trainability_value',
#        'trainability_category', 'demeanor_value', 'demeanor_category'],
#       dtype='str')

# %%
import pandas as pd
akc = pd.read_csv('data/raw/akc-dog-breeds.csv')
akc.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 277 entries, 0 to 276
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   277 non-null    str
#  1   description                  277 non-null    str
#  2   temperament                  276 non-null    str
#  3   popularity                   198 non-null    str
#  4   min_height                   277 non-null    float64
#  5   max_height                   277 non-null    float64
#  6   min_weight                   275 non-null    float64
#  7   max_weight                   275 non-null    float64
#  8   min_expectancy               274 non-null    float64
#  9   max_expectancy               274 non-null    float64
#  10  group                        277 non-null    str
#  11  grooming_frequency_value     270 non-null    float64
#  12  grooming_frequency_category  270 non-null    str
# ...

# %%
import pandas as pd
akc = pd.read_csv('data/raw/akc-dog-breeds.csv')
akc.describe()
# Out:
#        min_height  max_height  min_weight  max_weight  min_expectancy  \
# count  277.000000  277.000000  275.000000  275.000000      274.000000
# mean    44.225801   52.720588   17.888858   27.291416       11.306569
# std     14.238298   15.885454   12.290600   19.061416        1.817949
# min     12.700000   17.780000    0.000000    0.000000        0.000000
# 25%     33.020000   38.100000    8.164663   12.927383       10.000000
# 50%     45.085000   53.340000   15.875733   24.947580       12.000000
# 75%     55.880000   66.040000   22.679619   34.019428       12.000000
# max     76.200000   88.900000   68.038855  108.862169       16.000000
#
#        max_expectancy  grooming_frequency_value  shedding_value  \
# count      274.000000                270.000000      257.000000
# mean        13.832117                  0.425926        0.529183
# std          2.016668                  0.198306        0.189068
# min          0.000000                  0.200000        0.200000
# ...

# %%
import pandas as pd
dogtime = pd.read_csv('data/raw/dogtime-dataset.csv')
dogtime.shape
# Out:
# (349, 37)

# %%
import pandas as pd
dogtime = pd.read_csv('data/raw/dogtime-dataset.csv')
dogtime.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 349 entries, 0 to 348
# Data columns (total 37 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   breed                               349 non-null    str
#  1   url                                 349 non-null    str
#  2   a_adaptability                      349 non-null    int64
#  3   a1_adapts_well_to_apartment_living  349 non-null    int64
#  4   a2_good_for_novice_owners           349 non-null    int64
#  5   a3_sensitivity_level                349 non-null    int64
#  6   a4_tolerates_being_alone            349 non-null    int64
#  7   a5_tolerates_cold_weather           349 non-null    int64
#  8   a6_tolerates_hot_weather            349 non-null    int64
#  9   b_all_around_friendliness           349 non-null    int64
#  10  b1_affectionate_with_family         349 non-null    int64
# ...

# %%
import pandas as pd
austin = pd.read_csv('data/raw/aac_intakes_outcomes.csv')
austin.shape
# Out:
# (79672, 41)

# %%
import pandas as pd
austin = pd.read_csv('data/raw/aac_intakes_outcomes.csv')
austin.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 79672 entries, 0 to 79671
# Data columns (total 41 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   age_upon_outcome            79672 non-null  str
#  1   animal_id_outcome           79672 non-null  str
#  2   date_of_birth               79672 non-null  str
#  3   outcome_subtype             36348 non-null  str
#  4   outcome_type                79662 non-null  str
#  5   sex_upon_outcome            79671 non-null  str
#  6   age_upon_outcome_(days)     79672 non-null  int64
#  7   age_upon_outcome_(years)    79672 non-null  float64
#  8   age_upon_outcome_age_group  79672 non-null  str
#  9   outcome_datetime            79672 non-null  str
#  10  outcome_month               79672 non-null  int64
#  11  outcome_year                79672 non-null  int64
#  12  outcome_monthyear           79672 non-null  str
#  13  outcome_weekday             79672 non-null  str
# ...

# %%
import pandas as pd
austin = pd.read_csv('data/raw/aac_intakes_outcomes.csv')
austin['animal_type'].value_counts()
# Out:
# animal_type
# Dog      45366
# Cat      29539
# Other     4428
# Bird       339
# Name: count, dtype: int64

# %%
import pandas as pd
austin = pd.read_csv('data/raw/aac_intakes_outcomes.csv')
austin['breed'].value_counts()
# Out:
# breed
# Domestic Shorthair Mix              23423
# Pit Bull Mix                         6256
# Chihuahua Shorthair Mix              4831
# Labrador Retriever Mix               4789
# Domestic Medium Hair Mix             2326
#                                     ...
# Golden Retriever/Border Terrier         1
# Pomeranian/Beagle                       1
# Yorkshire Terrier/Dachshund             1
# Norfolk Terrier/Pug                     1
# Australian Shepherd/Basset Hound        1
# Name: count, Length: 2155, dtype: int64

# %%
import pandas as pd
austin = pd.read_csv('data/raw/aac_intakes_outcomes.csv')
dogs = austin[austin['animal_type'] == 'Dog']
dogs['breed'].value_counts().head(30)
# Out:
# breed
# Pit Bull Mix                     6256
# Chihuahua Shorthair Mix          4831
# Labrador Retriever Mix           4789
# German Shepherd Mix              1950
# Australian Cattle Dog Mix        1099
# Dachshund Mix                     811
# Boxer Mix                         683
# Border Collie Mix                 662
# Miniature Poodle Mix              662
# Catahoula Mix                     480
# Rat Terrier Mix                   469
# Australian Shepherd Mix           468
# Yorkshire Terrier Mix             447
# Siberian Husky Mix                441
# Jack Russell Terrier Mix          429
# Miniature Schnauzer Mix           402
# Beagle Mix                        392
# Staffordshire Mix                 375
# Chihuahua Longhair Mix            371
# Great Pyrenees Mix                349
# Cairn Terrier Mix                 348
# Pointer Mix                       336
# Rottweiler Mix                    325
# American Bulldog Mix              318
# ...

# %%
import pandas as pd
austin = pd.read_csv('data/raw/aac_intakes_outcomes.csv')
dogs = austin[austin['animal_type'] == 'Dog']
dogs['time_in_shelter_days'].describe()
# Out:
# count    45366.000000
# mean        15.897242
# std         44.430504
# min          0.000000
# 25%          2.093229
# 50%          5.064583
# 75%         11.116667
# max       1606.194444
# Name: time_in_shelter_days, dtype: float64
