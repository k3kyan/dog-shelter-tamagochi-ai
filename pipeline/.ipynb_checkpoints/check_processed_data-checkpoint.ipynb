# %%
import pandas as pd
df = pd.read_parquet('data/processed/breed_profiles.parquet')
df.shape
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_parquet('data/processed/breed_profiles.parquet')
#       3 df.shape
#
# File ~\OneDrive\Documents\GitHub\dog-shelter-tamagochi-ai\pipeline\pipelinevenv\Lib\site-packages\pandas\io\parquet.py:671, in read_parquet(path, engine, columns, storage_options, dtype_backend, filesystem, filters, to_pandas_kwargs, **kwargs)
#     668 impl = get_engine(engine)
#     669 check_dtype_backend(dtype_backend)
# --> 671 return impl.read(
#     672     path,
#     673     columns=columns,
#     674     filters=filters,
#     675     storage_options=storage_options,
#     676     dtype_backend=dtype_backend,
#     677     filesystem=filesystem,
#     678     to_pandas_kwargs=to_pandas_kwargs,
#     679     **kwargs,
#     680 )
#
# ...

# %%
import pandas as pd
df = pd.read_parquet('data/processed/breed_profiles.parquet')
df['personality_type'].value_counts()

# %%
import pandas as pd
df = pd.read_parquet('data/processed/breed_profiles.parquet')
df['starting_trust'].describe()

# %%
import pandas as pd
df = pd.read_parquet('data/processed/breed_profiles_raw.parquet')
df.isnull().sum()

# %%
import pandas as pd
df = pd.read_parquet('data/processed/breed_profiles.parquet')
df.duplicated(subset=['breed']).sum()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_parquet('data/processed/breed_profiles.parquet')
#       3 df.duplicated(subset=['breed']).sum()
#
# File ~\OneDrive\Documents\GitHub\dog-shelter-tamagochi-ai\pipeline\pipelinevenv\Lib\site-packages\pandas\io\parquet.py:671, in read_parquet(path, engine, columns, storage_options, dtype_backend, filesystem, filters, to_pandas_kwargs, **kwargs)
#     668 impl = get_engine(engine)
#     669 check_dtype_backend(dtype_backend)
# --> 671 return impl.read(
#     672     path,
#     673     columns=columns,
#     674     filters=filters,
#     675     storage_options=storage_options,
#     676     dtype_backend=dtype_backend,
#     677     filesystem=filesystem,
#     678     to_pandas_kwargs=to_pandas_kwargs,
#     679     **kwargs,
#     680 )
#
# ...
